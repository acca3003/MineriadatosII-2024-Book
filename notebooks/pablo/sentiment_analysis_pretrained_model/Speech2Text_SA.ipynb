# %% [markdown]
# # Tratamiento de textos con modelos pre-entrenados
#
# ## Análisis de Sentimientos
#
# A partir de los audios transcritos, se emplea el siguiente modelo para predecir el sentimiento de la oración.
#
# - Modelo utilizado: https://huggingface.co/siebert/sentiment-roberta-large-english

# %%
import pandas as pd
import json

with open('../audios/speech2text_audios.json') as f:
    data = json.load(f)

# %%
from transformers import pipeline
sentiment_analysis = pipeline("sentiment-analysis", model="siebert/sentiment-roberta-large-english")
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at siebert/sentiment-roberta-large-english.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %% [markdown]
# Aplicación del modelo:

# %%
results_dict = {}
for name, text in data.items():
    text = text.strip() # quitar espacios delante y atrás del text
    
    d = sentiment_analysis(text)[0] # el resultado es una lista de diccionarios (la lista es de un único elemento)
    d["text"] = text # añadimos el texto al diccionario que nos proporciona las predicciones 
    results_dict[name] = d

# %%
pd.DataFrame(results_dict).T
# Out:
#                  label     score  \
# audio_1.wav   POSITIVE  0.998897
# audio_10.wav  POSITIVE  0.998802
# audio_11.wav  POSITIVE  0.998792
# audio_12.wav  POSITIVE  0.998802
# audio_14.wav  POSITIVE  0.998716
# audio_16.wav  POSITIVE  0.998636
# audio_17.wav  POSITIVE   0.99806
# audio_18.wav  POSITIVE  0.998636
# audio_2.wav   POSITIVE  0.998905
# audio_20.wav  POSITIVE  0.998757
# audio_21.wav  POSITIVE  0.998778
# audio_22.wav  POSITIVE  0.998363
# audio_24.wav  POSITIVE  0.998286
# audio_28.wav  POSITIVE  0.998799
# audio_29.wav  POSITIVE  0.998711
# audio_3.wav   POSITIVE  0.998897
# audio_30.wav  POSITIVE  0.998799
# audio_31.wav  POSITIVE   0.99878
# audio_32.wav  NEGATIVE  0.999386
# audio_36.wav  POSITIVE  0.998811
# audio_37.wav  POSITIVE  0.998812
# audio_38.wav  POSITIVE  0.997573
# audio_39.wav  POSITIVE  0.998812
# audio_40.wav  POSITIVE  0.998832
# audio_43.wav  POSITIVE  0.998803
# audio_44.wav  POSITIVE  0.996856
# audio_46.wav  POSITIVE  0.998742
# audio_47.wav  POSITIVE  0.998763
# audio_48.wav  POSITIVE  0.998742
# audio_49.wav  POSITIVE  0.997857
# audio_5.wav   POSITIVE  0.998676
# audio_50.wav  POSITIVE  0.998506
# audio_6.wav   POSITIVE  0.998736
# audio_9.wav   POSITIVE  0.998741
#
#                                                           text
# audio_1.wav                           I like talking with you.
# audio_10.wav                    Thank you for your great help.
# audio_11.wav                    Thank you for the good health.
# audio_12.wav                    Thank you for your great help.
# audio_14.wav                             I like your attitude.
# audio_16.wav                   I have a great respect for you.
# audio_17.wav                    I want to go to his portfolio.
# audio_18.wav                   I have a great respect for you.
# audio_2.wav                           I love talking with you.
# audio_20.wav                       You love doing a great job.
# audio_21.wav                        You have done a great job.
# audio_22.wav                        Wow! Wonderful suggestion.
# audio_24.wav                          Wow wonderful suggestion
# audio_28.wav                     You are a very caring person.
# audio_29.wav                       You are a very good person.
# audio_3.wav                           I like talking with you.
# audio_30.wav                     You are a very caring person.
# audio_31.wav                  Everyone loves to talk with you.
# audio_32.wav      We're leaving the last street down cold too.
# audio_36.wav                      I am very much proud of you.
# audio_37.wav  I understood everything you taught me very well.
# audio_38.wav         I must be the ultimate partner, everyone.
# audio_39.wav  I understood everything you taught me very well.
# audio_40.wav                  A great thanks for your support.
# audio_43.wav                      You are a brilliant student.
# audio_44.wav                          You are a blaster, Dave.
# audio_46.wav                   You are a very hardworking guy.
# audio_47.wav                  You are a very hard working man.
# audio_48.wav                   You are a very hardworking guy.
# audio_49.wav                  You are an idol for many people.
# audio_5.wav                            You have a great voice.
# audio_50.wav                 You are an adult for many people.
# audio_6.wav                            You have a great piece.
# audio_9.wav                            You are a great leader.
